# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('species',axis =1 )
y = df['species']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model_knn = KNeighborsClassifier(n_neighbors=13)

# %%
model_knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=13)

# %%
model_knn.score(X_test,y_test)
# Out:
# 1.0

# %%
# 100% accuracy means its an overfit when n_neighbout = 13

# %%
from sklearn.svm import SVC

# %%
model_svm = SVC(gamma='auto')

# %%
model_svm.fit(X_train, y_train)
# Out:
# SVC(gamma='auto')

# %%
model_svm.score(X_test,y_test)                   # by changing the hyper parameters we may get various accuracies
# Out:
# 1.0

# %% [markdown]
# # now lets use the grid search cv

# %%
from sklearn.model_selection import GridSearchCV

# %%
classifier = GridSearchCV((model_svm),{
    'C' : [1,10,20,30],
    'kernel' : ['rbf','linear'],
 }, cv = 5, return_train_score=False)

# %%
classifier.fit(X,y)            # we don't reeally have to train & test our data in GridSearchCV
# Out:
# GridSearchCV(cv=5, estimator=SVC(gamma='auto'),
#              param_grid={'C': [1, 10, 20, 30], 'kernel': ['rbf', 'linear']})

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([0.00212216, 0.00138416, 0.00144529, 0.00134439, 0.00137634,
#         0.00129533, 0.00130739, 0.00167975]),
#  'std_fit_time': array([6.58613915e-04, 1.07937818e-04, 1.48834543e-04, 3.86530565e-05,
#         8.83162921e-05, 4.43958186e-05, 9.51478337e-06, 2.76502717e-04]),
#  'mean_score_time': array([0.00142756, 0.00105119, 0.00112705, 0.00105047, 0.00102744,
#         0.00097432, 0.0010015 , 0.00119934]),
#  'std_score_time': array([2.49318566e-04, 6.61577834e-05, 1.42204113e-04, 5.55864110e-05,
#         2.70100367e-05, 2.23476438e-05, 7.31070832e-06, 2.31161025e-04]),
#  'param_C': masked_array(data=[1, 1, 10, 10, 20, 20, 30, 30],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value=999999),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'rbf', 'linear', 'rbf', 'linear',
#                     'rbf', 'linear'],
#               mask=[False, False, False, False, False, False, False, False],
# ...

# %%
results = pd.DataFrame(classifier.cv_results_)

# %%
results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.002122      0.000659         0.001428        0.000249        1
# 1       0.001384      0.000108         0.001051        0.000066        1
# 2       0.001445      0.000149         0.001127        0.000142       10
# 3       0.001344      0.000039         0.001050        0.000056       10
# 4       0.001376      0.000088         0.001027        0.000027       20
# 5       0.001295      0.000044         0.000974        0.000022       20
# 6       0.001307      0.000010         0.001002        0.000007       30
# 7       0.001680      0.000277         0.001199        0.000231       30
#
#   param_kernel                         params  split0_test_score  \
# 0          rbf      {'C': 1, 'kernel': 'rbf'}           0.966667
# 1       linear   {'C': 1, 'kernel': 'linear'}           0.966667
# 2          rbf     {'C': 10, 'kernel': 'rbf'}           0.966667
# ...

# %%
results[['param_C','param_kernel','mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0        1          rbf         0.980000
# 1        1       linear         0.980000
# 2       10          rbf         0.980000
# 3       10       linear         0.973333
# 4       20          rbf         0.966667
# 5       20       linear         0.966667
# 6       30          rbf         0.960000
# 7       30       linear         0.960000

# %%
# now with knn model

# %%
classifier2 = GridSearchCV((model_knn),{
    'n_neighbors' : [3,5,7,9,11,13]
 }, cv = 5, return_train_score=False)

# %%
classifier2.fit(X,y)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(n_neighbors=13),
#              param_grid={'n_neighbors': [3, 5, 7, 9, 11, 13]})

# %%
classifier2.cv_results_
# Out:
# {'mean_fit_time': array([0.00509977, 0.00477376, 0.00434523, 0.00414233, 0.00421247,
#         0.0044064 ]),
#  'std_fit_time': array([8.20278905e-04, 7.24123040e-04, 1.51774908e-04, 1.94894028e-05,
#         3.85125642e-05, 3.36141024e-04]),
#  'mean_score_time': array([0.01071429, 0.0104342 , 0.00966492, 0.01005135, 0.01133246,
#         0.01194692]),
#  'std_score_time': array([0.00125064, 0.000525  , 0.00010843, 0.0004169 , 0.00218647,
#         0.00325557]),
#  'param_n_neighbors': masked_array(data=[3, 5, 7, 9, 11, 13],
#               mask=[False, False, False, False, False, False],
#         fill_value=999999),
#  'params': [{'n_neighbors': 3},
#   {'n_neighbors': 5},
#   {'n_neighbors': 7},
#   {'n_neighbors': 9},
#   {'n_neighbors': 11},
#   {'n_neighbors': 13}],
#  'split0_test_score': array([0.96666667, 0.96666667, 0.96666667, 0.96666667, 0.93333333,
#         0.93333333]),
#  'split1_test_score': array([0.96666667, 1.        , 1.        , 1.        , 1.        ,
# ...

# %%
results2 = pd.DataFrame(classifier2.cv_results_)

# %%
results2
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.005100      0.000820         0.010714        0.001251
# 1       0.004774      0.000724         0.010434        0.000525
# 2       0.004345      0.000152         0.009665        0.000108
# 3       0.004142      0.000019         0.010051        0.000417
# 4       0.004212      0.000039         0.011332        0.002186
# 5       0.004406      0.000336         0.011947        0.003256
#
#    param_n_neighbors               params  split0_test_score  \
# 0                  3   {'n_neighbors': 3}           0.966667
# 1                  5   {'n_neighbors': 5}           0.966667
# 2                  7   {'n_neighbors': 7}           0.966667
# 3                  9   {'n_neighbors': 9}           0.966667
# 4                 11  {'n_neighbors': 11}           0.933333
# 5                 13  {'n_neighbors': 13}           0.933333
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# ...

# %% [markdown]
# # Random Search CV

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
classifier3 = RandomizedSearchCV((model_svm),{
    'C' : [1,10,20,30],
    'kernel' : ['rbf','linear']
},n_iter=4, cv = 5,return_train_score = False)

# %%
classifier3.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(gamma='auto'), n_iter=4,
#                    param_distributions={'C': [1, 10, 20, 30],
#                                         'kernel': ['rbf', 'linear']})

# %%
classifier3.cv_results_
# Out:
# {'mean_fit_time': array([0.0051857 , 0.00422578, 0.00426631, 0.00442982]),
#  'std_fit_time': array([0.00083502, 0.00047575, 0.00054768, 0.00011028]),
#  'mean_score_time': array([0.00387025, 0.00328026, 0.00322418, 0.00360713]),
#  'std_score_time': array([0.00041989, 0.0002745 , 0.00031899, 0.00026756]),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'linear', 'rbf'],
#               mask=[False, False, False, False],
#         fill_value=np.str_('?'),
#              dtype=object),
#  'param_C': masked_array(data=[1, 10, 30, 20],
#               mask=[False, False, False, False],
#         fill_value=999999),
#  'params': [{'kernel': 'rbf', 'C': 1},
#   {'kernel': 'linear', 'C': 10},
#   {'kernel': 'linear', 'C': 30},
#   {'kernel': 'rbf', 'C': 20}],
#  'split0_test_score': array([0.95, 0.95, 0.95, 0.95]),
#  'split1_test_score': array([0.9 , 0.85, 0.85, 0.8 ]),
#  'split2_test_score': array([0.9, 0.9, 0.9, 0.9]),
#  'split3_test_score': array([1., 1., 1., 1.]),
# ...

# %%
results3 = pd.DataFrame(classifier3.cv_results_)

# %%
results3
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_kernel  \
# 0       0.005186      0.000835         0.003870        0.000420          rbf
# 1       0.004226      0.000476         0.003280        0.000275       linear
# 2       0.004266      0.000548         0.003224        0.000319       linear
# 3       0.004430      0.000110         0.003607        0.000268          rbf
#
#    param_C                         params  split0_test_score  \
# 0        1      {'kernel': 'rbf', 'C': 1}               0.95
# 1       10  {'kernel': 'linear', 'C': 10}               0.95
# 2       30  {'kernel': 'linear', 'C': 30}               0.95
# 3       20     {'kernel': 'rbf', 'C': 20}               0.95
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0               0.90                0.9                1.0               0.95
# 1               0.85                0.9                1.0               0.95
# ...

# %%
results3[['param_C','param_kernel','mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0        1          rbf             0.94
# 1       10       linear             0.93
# 2       30       linear             0.94
# 3       20          rbf             0.92
